# %%
print("house prediction main")
# Out:
# house prediction main

# %%
import importlib
import eda.data_ingestor

importlib.reload(eda.data_ingestor)
# Out:
# <module 'eda.data_ingestor' from '/Users/Kavyapriya/AI_Learnings/e2e-mlops-setup/eda/data_ingestor.py'>

# %%
from eda.data_ingestor import DataIngestorFactory

# %%
file_path = "/Users/Kavyapriya/AI_Learnings/e2e-mlops-setup/data/Housing.csv"
file_type = file_path[-4:]
data_ingestor_factory = DataIngestorFactory()
ingestor = data_ingestor_factory.get_data_ingestor(file_type)
df = ingestor.ingest(file_path)
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
